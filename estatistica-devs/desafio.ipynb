# %% [markdown]
# # Desafio - Estatística para Devs
#
# ## Exercício do módulo
#
# Com base nas aulas do módulo de Estatística, utilize os métodos da biblioteca Pandas para tratar o dicionário abaixo e:
# - Trazer a média das vendas
# - Criar um gráfico de barras vertical mostrando o mês de referência e o valor
# - Criar um gráfico de linhas mostrando o mês de referência e o valor.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dicionário de faturamento
dict_faturamento = {
    'data_ref': [
        '2023-01-01', 
        '2020-02-01', 
        '2021-03-01', 
        '2022-04-01', 
        '2023-05-01',
        '2023-06-01', 
        '2020-07-01', 
        '2021-08-01', 
        '2022-09-01', 
        '2023-10-01',
        '2022-11-01', 
        '2023-12-01',
        ],
    'valor': [
        400000, 
        890000, 
        760000, 
        430000, 
        920000,
        340000, 
        800000, 
        500000, 
        200000, 
        900000,
        570000, 
        995000,
        ]
}

# %%
# Criar o DataFrame de faturamento e corrigir o tipo de dados das colunas
def_faturamento = pd.DataFrame.from_dict(dict_faturamento)
def_faturamento['data_ref'] = pd.to_datetime(def_faturamento['data_ref'])
def_faturamento['month'] = def_faturamento['data_ref'].dt.strftime('%y/%m')
def_faturamento.sort_values('data_ref',inplace=True)
def_faturamento
# Out:
#      data_ref   valor  month
# 1  2020-02-01  890000  20/02
# 6  2020-07-01  800000  20/07
# 2  2021-03-01  760000  21/03
# 7  2021-08-01  500000  21/08
# 3  2022-04-01  430000  22/04
# 8  2022-09-01  200000  22/09
# 10 2022-11-01  570000  22/11
# 0  2023-01-01  400000  23/01
# 4  2023-05-01  920000  23/05
# 5  2023-06-01  340000  23/06
# 9  2023-10-01  900000  23/10
# 11 2023-12-01  995000  23/12

# %%
# Média de vendas
def_faturamento.valor.mean()
# Out:
# 642083.3333333334

# %%
# Gráfico de barras vertical
def_faturamento.plot.bar(x='month', y='valor')
# Out:
# <Axes: xlabel='month'>

# %%
# Gráfico de linhas
def_faturamento.plot.line(x='month', y='valor')
# Out:
# <Axes: xlabel='month'>
